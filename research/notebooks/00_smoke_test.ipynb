# %% [markdown]
# # Smoke test
#
# Verifies that the venv + Jupyter + project imports all work end-to-end.
# Loads the NQ 15-min CSV via `engine.data_loader` and plots the closing price.

# %%
import sys
from pathlib import Path

# Make the project root importable (notebook lives in research/notebooks/)
PROJECT_ROOT = Path.cwd().parents[1]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import matplotlib.pyplot as plt
from engine.data_loader import load_csv

print(f'Project root: {PROJECT_ROOT}')
print(f'pandas: {pd.__version__}')

# %%
df = load_csv(str(PROJECT_ROOT / 'data' / 'nq_15m_data.csv'), session_filter=True)
print(f'Rows: {len(df):,}')
print(f'Range: {df.index.min()}  ->  {df.index.max()}')
df.head()

# %%
fig, ax = plt.subplots(figsize=(12, 4))
df['close'].plot(ax=ax, linewidth=0.5)
ax.set_title('NQ 15m close (RTH only)')
ax.set_ylabel('Price')
plt.tight_layout()
plt.show()
